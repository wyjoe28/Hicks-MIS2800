# %% [markdown]
# <a href="https://colab.research.google.com/github/wyjoe28/Hicks-MIS2800/blob/main/Hicks_HW4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 57.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 46.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 500000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# -- Instructions: Fix the code to select all the columns from the Marketing_Brands table
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 500000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# -- Instructions: Fix the code to display only the brand names and
# brand types that had budget over 700000
# %%sql
SELECT brand_name, brand_type FROM Marketing_Brands WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Google', 'Technology')]

# %%
# %%sql
# -- Instructions: Fix the code to find the brand types that are Religious
# SELECT brand_type FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
# -- Instructions: Fix the code to display the
# brand names that have a budget under 1000000
# %%sql
SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Dr_Pepper',), ('IBM',)]

# %%
# Instructins: Fix the code so that this will run SQLite3 in
# Colab without having to wrap in Python.  Hint: It's Magic!
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# --Instructions: Find the brands where the brand type is
# -- Snacks or Beverages.  Display only the brand names.
# SELECT brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
# %%sql
# -- Instructions: Sort the table by brand budget in
# -- DESC order. Display only the brand_name and brand_budget.
# SELECT brand_name, brand_budget FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('Dr_Pepper', 500000),
#  ('IBM', 100000)]

# %%
# Using SQLite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.
# %%sql
SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (5, 'Dr_Pepper', 'Beverages', 500000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 1. I fixed the code by adding the TABLE keyword to the CREATE statement, changing CREATE Marketing_Brands to CREATE TABLE Marketing_Brands.
# 2. I fixed the code by adding the INTO keyword and specifying the table name Marketing_Brands to the INSERT statement, changing INSERT (brand_id, brand_name, brand_type, brand_budget) to INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget).
# 3. I fixed the code by adding the * to the SELECT statement to select all columns, changing SELECT FROM Marketing_Brands; to SELECT * FROM Marketing_Brands;.
# 4.  I fixed the code by specifying the brand_name, brand_type columns to select and added the WHERE brand_budget > 700000 clause. I also changed the # comment to -- to ensure valid SQL syntax.
# 5. I fixed the code by specifying brand_type to select and added the WHERE brand_type = 'Religious' clause to filter the results.
# 6.  I fixed the code by specifying brand_name to select and added the WHERE brand_budget < 1000000 clause to filter the results.
# 7. I fixed the code by adding the %%sql magic command at the beginning of the cell. This allows for the direct execution of SQLite3 queries within Colab without needing to wrap them in Python code.
# 8.  I fixed the code by specifying brand_name to select and added the WHERE brand_type = 'Snacks' OR brand_type = 'Beverages' clause to filter the results. I also changed the # comment to -- for proper SQL commenting.
# 9. I fixed the code by specifying brand_name, brand_budget to select and added the ORDER BY brand_budget DESC clause to sort the results. I also changed the # comment to -- for proper SQL commenting.
# 10. I added the %%sql magic command and the full SQL query SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC; to display all columns sorted by budget in ascending order.
